# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json
# Import API key
from api_keys import geoapify_key
from pprint import pprint
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="c702301b-4555-4ca2-b122-3d7380f80bb9" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"de510232-063e-493e-a26a-edb7d9d55f7a":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"9dbaf7fa86464cfab5fa1412cc0974ee","client_comm_id":"74a156cde4594c0ba1b0932cd2bfdb54"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"de510232-063e-493e-a26a-edb7d9d55f7a","roots":{"p1002":"c702301b-4555-4ca2-b122-3d7380f80bb9"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                         City      Lat       Lng  Max Temp  \
# 0        0                       nemuro  43.3236  145.5750     20.32
# 1        1  edinburgh of the seven seas -37.0676  -12.3116     10.71
# 2        2                      udachny  66.4167  112.4000      0.14
# 3        3                         lebu -37.6167  -73.6500      7.98
# 4        4                       boende  -0.2167   20.8667     22.06
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        67           0        2.60      JP  1726629757
# 1        75         100        7.20      SH  1726629759
# 2        66          99        8.01      RU  1726629761
# 3        88         100        1.62      CL  1726629762
# 4        91          53        1.13      CD  1726629763

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot= city_data_df.hvplot.points(
    'Lng',
    'Lat',
    size='Humidity',
    geo=True,
    tiles='OSM',
    frame_width=800,
    frame_height=600,
)

# Display the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_temp_range = (15, 40)
ideal_humidity = 70

# Drop any rows with null values
ideal_weather_df = city_data_df[
(city_data_df['Max Temp'].between(ideal_temp_range[0], ideal_temp_range[1])) &
(city_data_df['Humidity'] == ideal_humidity)
]


# Display sample data
ideal_weather_df
# Out:
#      City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 57        57   manokwari  -0.8667  134.0833     29.30        70          77
# 186      186        ta`u -14.2336 -169.5144     26.92        70          20
# 194      194     machico  32.7000  -16.7667     22.35        70          75
# 256      256    tangalle   6.0240   80.7911     29.15        70          33
# 296      296  torrevieja  37.9787   -0.6822     23.47        70          15
# 329      329        tura  25.5198   90.2201     29.72        70           0
# 363      363     angicos  -5.6656  -36.6011     23.50        70          40
# 485      485        nisa  43.7031    7.2661     18.37        70          75
#
#      Wind Speed Country        Date
# 57         6.23      ID  1726629826
# 186        1.10      AS  1726629985
# 194        4.12      PT  1726629994
# 256        6.13      LK  1726630073
# 296        1.79      ES  1726630120
# 329        0.58      IN  1726630162
# 363       10.18      BR  1726629953
# 485        5.14      FR  1726630356

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df.head()
# Out:
#            City Country      Lat       Lng  Humidity Hotel Name
# 57    manokwari      ID  -0.8667  134.0833        70
# 186        ta`u      AS -14.2336 -169.5144        70
# 194     machico      PT  32.7000  -16.7667        70
# 256    tangalle      LK   6.0240   80.7911        70
# 296  torrevieja      ES  37.9787   -0.6822        70

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
latitude = 16.8634
longitude = -99.8901
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "apiKey": geoapify_key,
    "limit": 1,
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    latitude = row["Lat"]
    longitude = row["Lng"]

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)

    data = {}
    
    if name_address.status_code == 200:

        data = name_address.json()
        print(data)
    else:
        print(f"Error: {name_address.status_code}")
   
    # Convert the API response to JSON format
    name_address = data

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address['features'][0]["properties"]["name"]
    except (KeyError, IndexError):
         #If no hotel is found, set the hotel name as "No hotel found"
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
   
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
    #print(f"Request URL: {base_url}?{requests.compat.urlencode(params)}")
# Display sample data
hotel_df
# Out:
# Starting hotel search
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Hotel Arfak', 'country': 'Indonesia', 'country_code': 'id', 'region': 'Western New Guinea', 'state': 'West Papua', 'county': 'Manokwari', 'city': 'Manokwari', 'postcode': '98311', 'street': 'Jalan Brawijaya', 'lon': 134.07749540377083, 'lat': -0.86482445, 'formatted': 'Hotel Arfak, Jalan Brawijaya, Manokwari 98311, West Papua, Indonesia', 'address_line1': 'Hotel Arfak', 'address_line2': 'Jalan Brawijaya, Manokwari 98311, West Papua, Indonesia', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation'], 'details': ['details', 'details.accommodation', 'details.facilities'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Hotel Arfak', 'stars': 2, 'osm_id': 182809406, 'smoking': 'yes', 'tourism': 'hotel', 'building': 'yes', 'operator': 'Pemda Kab Manokwari', 'osm_type': 'w', 'wheelchair': 'no', 'internet_access': 'no'}}, 'operator': 'Pemda Kab Manokwari', 'facilities': {'internet_access': False, 'wheelchair': False, 'smoking': True}, 'accommodation': {'stars': 2}, 'distance': 645, 'place_id': '512619a4d77ac2604059cd4c2553a4acebbff00102f9013e73e50a0000000092030b486f74656c20417266616b'}, 'geometry': {'type': 'Point', 'coordinates': [134.0774954037708, -0.8648244499148859]}}]}
# manokwari - nearest hotel: Hotel Arfak
# {'type': 'FeatureCollection', 'features': []}
# ta`u - nearest hotel: No hotel found
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Residence Inn', 'country': 'Portugal', 'country_code': 'pt', 'city': 'Machico', 'village': 'Água de Pena', 'postcode': '9100-222', 'district': 'Bemposta', 'street': 'Caminho da Bemposta', 'lon': -16.78047665, 'lat': 32.70348485, 'formatted': 'Residence Inn, Caminho da Bemposta, 9100-222 Machico, Portugal', 'address_line1': 'Residence Inn', 'address_line2': 'Caminho da Bemposta, 9100-222 Machico, Portugal', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation'], 'details': ['details'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Residence Inn', 'osm_id': 576470701, 'tourism': 'hotel', 'building': 'yes', 'operator': 'Prisma', 'osm_type': 'w'}}, 'operator': 'Prisma', 'distance': 1334, 'place_id': '51a90a5751cdc730c059661ca3ca0b5a4040f00102f901ad3e5c220000000092030d5265736964656e636520496e6e'}, 'geometry': {'type': 'Point', 'coordinates': [-16.78047665, 32.70348484959031]}}]}
# machico - nearest hotel: Residence Inn
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Coco Tangalla', 'country': 'Sri Lanka', 'country_code': 'lk', 'state': 'Southern Province', 'county': 'Hambantota District', 'city': 'Tangalle', 'postcode': '82300', 'suburb': 'Kotuwegoda', 'street': 'Matara-Hambantota Road', 'housenumber': '355', 'lon': 80.79583218859406, 'lat': 6.02033355, 'formatted': 'Coco Tangalla, 355 Matara-Hambantota Road, Kotuwegoda, Tangalle 82300, Sri Lanka', 'address_line1': 'Coco Tangalla', 'address_line2': '355 Matara-Hambantota Road, Kotuwegoda, Tangalle 82300, Sri Lanka', 'categories': ['accommodation', 'accommodation.hotel'], 'details': ['details', 'details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Coco Tangalla', 'phone': '+94 81 7 201115', 'osm_id': 397033586, 'landuse': 'residential', 'tourism': 'hotel', 'website': 'https://www.cocotangalla.com/', 'operator': 'Manor House Concept', 'osm_type': 'w', 'addr:city': 'Tangalle', 'addr:street': 'Mahawella Road', 'addr:housenumber': 355}}, 'website': 'https://www.cocotangalla.com/', 'operator': 'Manor House Concept', 'contact': {'phone': '+94 81 7 201115'}, 'distance': 627, 'place_id': '5166c721eaee32544059b07d6751d2141840f00102f9017240aa170000000092030d436f636f2054616e67616c6c61'}, 'geometry': {'type': 'Point', 'coordinates': [80.79583218859406, 6.020333549443805]}}]}
# tangalle - nearest hotel: Coco Tangalla
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Hotel Fontana Plaza', 'country': 'Spain', 'country_code': 'es', 'state': 'Valencian Community', 'county': 'el Baix Segura / La Vega Baja del Segura', 'province': 'Alacant / Alicante', 'city': 'Torrevieja', 'postcode': '03181', 'suburb': 'Europa', 'street': 'Rambla Juan Mateo García', 'housenumber': '19', 'lon': -0.6797752830280523, 'lat': 37.9770314, 'formatted': 'Hotel Fontana Plaza, Rambla Juan Mateo García, 19, 03181 Torrevieja, Spain', 'address_line1': 'Hotel Fontana Plaza', 'address_line2': 'Rambla Juan Mateo García, 19, 03181 Torrevieja, Spain', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation'], 'details': ['details', 'details.accommodation', 'details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Hotel Fontana Plaza', 'email': 'fontanaplaza@hotelfontanaplaza.com', 'phone': '+34 96 692 89 25', 'rooms': 100, 'stars': 3, 'osm_id': 693874313, 'tourism': 'hotel', 'website': 'https://www.hotelfontanaplaza.com/', 'building': 'yes', 'osm_type': 'w', 'addr:street': 'Rambla Juan Mateo García', 'addr:housenumber': 19}}, 'website': 'https://www.hotelfontanaplaza.com/', 'contact': {'phone': '+34 96 692 89 25', 'email': 'fontanaplaza@hotelfontanaplaza.com'}, 'accommodation': {'stars': 3, 'rooms': 100}, 'distance': 268, 'place_id': '5112822718b8c0e5bf5974096b5d0ffd4240f00102f90189ae5b2900000000920313486f74656c20466f6e74616e6120506c617a61'}, 'geometry': {'type': 'Point', 'coordinates': [-0.6797752830280521, 37.977031399978756]}}]}
# torrevieja - nearest hotel: Hotel Fontana Plaza
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Hotel Polo Orchid', 'country': 'India', 'country_code': 'in', 'state': 'Meghalaya', 'state_district': 'West Garo Hills District', 'county': 'Rongram', 'postcode': '794101', 'street': 'NH 127B', 'lon': 90.1922126, 'lat': 25.5143722, 'state_code': 'ML', 'formatted': 'Hotel Polo Orchid, NH 127B, - 794101, Meghalaya, India', 'address_line1': 'Hotel Polo Orchid', 'address_line2': 'NH 127B, - 794101, Meghalaya, India', 'categories': ['accommodation', 'accommodation.hotel'], 'details': [], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Hotel Polo Orchid', 'osm_id': 11350592321, 'tourism': 'hotel', 'osm_type': 'n'}}, 'distance': 2867, 'place_id': '5143b813364d8c5640598de181e5ad833940f00103f901414b8ca402000000920311486f74656c20506f6c6f204f7263686964'}, 'geometry': {'type': 'Point', 'coordinates': [90.19221259999999, 25.514372200211756]}}]}
# tura - nearest hotel: Hotel Polo Orchid
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Confort', 'country': 'Brazil', 'country_code': 'br', 'region': 'Northeast Region', 'state': 'Rio Grande do Norte', 'county': 'Região Geográfica Intermediária de Mossoró', 'city': 'Angicos', 'municipality': 'Região Geográfica Imediata de Açu', 'district': 'Angicos', 'street': 'Rua João Alexandre', 'lon': -36.6013355, 'lat': -5.6663799, 'state_code': 'RN', 'formatted': 'Confort, Rua João Alexandre, Angicos - RN, Brazil', 'address_line1': 'Confort', 'address_line2': 'Rua João Alexandre, Angicos - RN, Brazil', 'categories': ['accommodation', 'accommodation.hotel', 'internet_access'], 'details': ['details.facilities'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Confort', 'osm_id': 4255632689, 'tourism': 'hotel', 'osm_type': 'n', 'internet_access': 'wlan'}}, 'facilities': {'internet_access': True}, 'distance': 90, 'place_id': '513e36c98ff84c42c059d55d0f7e5faa16c0f00103f90131cda7fd00000000920307436f6e666f7274'}, 'geometry': {'type': 'Point', 'coordinates': [-36.60133549999999, -5.666379899680995]}}]}
# angicos - nearest hotel: Confort
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Hôtel du Centre', 'country': 'France', 'country_code': 'fr', 'region': 'Metropolitan France', 'state': "Provence-Alpes-Côte d'Azur", 'county': 'Maritime Alps', 'city': 'Nice', 'municipality': 'Nice', 'postcode': '06000', 'suburb': 'Quartier Jean-Médecin', 'street': 'Rue de Suisse', 'lon': 7.2656975, 'lat': 43.7035846, 'state_code': 'PAC', 'state_COG': '93', 'formatted': 'Hôtel du Centre, Rue de Suisse, 06000 Nice, France', 'address_line1': 'Hôtel du Centre', 'address_line2': 'Rue de Suisse, 06000 Nice, France', 'categories': ['accommodation', 'accommodation.hotel'], 'details': ['details', 'details.contact', 'details.wiki_and_media'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Hôtel du Centre', 'email': 'contact@hotelducentre-nice.com', 'phone': '+33493822980', 'osm_id': 9118025855, 'tourism': 'hotel', 'website': 'https://www.hotelducentre-nice.com/', 'osm_type': 'n', 'wikidata': 'Q111122965'}}, 'website': 'https://www.hotelducentre-nice.com/', 'contact': {'phone': '+33493822980', 'email': 'contact@hotelducentre-nice.com'}, 'wiki_and_media': {'wikidata': 'Q111122965'}, 'distance': 63, 'place_id': '510e84640113101d4059e4a4680f0fda4540f00103f9017f087a1f0200000092031048c3b474656c2064752043656e747265'}, 'geometry': {'type': 'Point', 'coordinates': [7.2656975, 43.703584600539926]}}]}
# nisa - nearest hotel: Hôtel du Centre
#            City Country      Lat       Lng  Humidity           Hotel Name
# 57    manokwari      ID  -0.8667  134.0833        70          Hotel Arfak
# 186        ta`u      AS -14.2336 -169.5144        70       No hotel found
# 194     machico      PT  32.7000  -16.7667        70        Residence Inn
# 256    tangalle      LK   6.0240   80.7911        70        Coco Tangalla
# 296  torrevieja      ES  37.9787   -0.6822        70  Hotel Fontana Plaza
# 329        tura      IN  25.5198   90.2201        70    Hotel Polo Orchid
# 363     angicos      BR  -5.6656  -36.6011        70              Confort
# 485        nisa      FR  43.7031    7.2661        70      Hôtel du Centre

# %%
hotel_df.head()
# Out:
#            City Country      Lat       Lng  Humidity           Hotel Name
# 57    manokwari      ID  -0.8667  134.0833        70          Hotel Arfak
# 186        ta`u      AS -14.2336 -169.5144        70       No hotel found
# 194     machico      PT  32.7000  -16.7667        70        Residence Inn
# 256    tangalle      LK   6.0240   80.7911        70        Coco Tangalla
# 296  torrevieja      ES  37.9787   -0.6822        70  Hotel Fontana Plaza

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map_plot= hotel_df.hvplot.points(
    'Lng',
    'Lat',
    size='Humidity',
    geo=True,
    tiles='OSM',
    frame_width=800,
    frame_height=600,
    hover_cols=['Hotel Name', 'Country']
)

# Display the map
hotel_map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Humidity,Hotel Name,Country)
