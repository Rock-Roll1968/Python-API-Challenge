# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
from pprint import pprint
# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
import random
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
cities = []


for i in range(500):
    lat = random.uniform(-90, 90)
    lon = random.uniform(-180, 180)
    city = citipy.nearest_city(lat, lon)
    cities.append(city.city_name)

    cities = list(set(cities))
pprint(f"Generated cities list: {cities}")
# Out:
# ("Generated cities list: ['igarka', 'kourou', 'lamu', 'taiohae', 'coxen hole', "
#  "'las palmas', 'siracusa', 'verkhnevilyuysk', 'margaret river', 'lorengau', "
#  '\'lerwick\', \'rundu\', "kapa\'a", \'bani walid\', \'mar del plata\', '
#  "'bitlis', 'grytviken', 'georgetown', 'albany', 'ola', 'fort st. john', "
#  '\'udachny\', \'whitehorse\', \'barakani\', \'vilyuysk\', "al \'alamayn", '
#  "'thompson', 'bamboo flat', 'cortez', 'port elizabeth', 'sinop', 'olinda', "
#  "'saint-francois', 'rio preto da eva', 'bredasdorp', 'gadzhiyevo', "
#  '\'san-pedro\', \'pama\', \'mana\', \'ocean city\', "severobaykal\'sk", '
#  "'howrah', 'ariquemes', 'inhambane', 'essaouira', 'komotini', 'dwarka', "
#  "'buka', 'fort bragg', 'saint-philippe', 'marakkanam', 'inari', "
#  "'vilyuchinsk', 'kasson', 'port macquarie', 'victoria de durango', 'bethel', "
#  "'sao joao do piaui', 'saint john', 'hede', 'yalutorovsk', 'stanley', "
#  "'edinburgh of the seven seas', 'akureyri', 'tolanaro', 'centenario', "
#  "'kalmunai', 'coahuayana de hidalgo', 'santa rosa de cabal', 'flying fish "
#  "cove', 'maumere', 'praia da vitoria', 'shahba', 'camacupa', 'kodiak', "
#  "'toliara', 'strezhevoy', 'avarua', 'cabo san lucas', 'san patricio', "
#  "'kirakira', 'alotau', 'fort wellington', 'hingoli', 'hulin', 'sitka', "
#  "'salalah', 'pianco', 'sinmak', 'zhangjiakou shi xuanhua qu', 'port "
#  "mathurin', 'klyuchi', 'petropavlovsk-kamchatsky', 'lodja', 'nantucket', 'san "
#  'andres\', \'yellowknife\', \'rongelap\', "cooper\'s town", \'lionel town\', '
#  "'port-aux-francais', 'rabo de peixe', 'longyearbyen', 'hawaiian paradise "
#  "park', 'anadyr', 'grand falls-windsor', 'berezovyy', 'agat village', "
#  "'codrington', 'isafjordur', 'winchester', 'ancud', 'boa vista', 'evanston', "
#  "'birobidzhan', 'kone', 'nurota', 'manaure', 'lebu', 'san fernando', "
#  "'galliano', 'jinchang', 'puerto ayora', 'anloga', 'laojunmiao', 'hithadhoo', "
#  "'puerto san carlos', 'kanniyakumari', 'hermanus', 'susuman', 'stephenville', "
#  "'umluj', 'waitangi', 'daru', 'keflavik', 'lompoc', 'chernolesskoye', 'puerto "
#  "deseado', 'west island', 'tiksi', 'berdigestyakh', 'tralee', 'constantia', "
#  "'atafu village', 'kuqa', 'enewetak', 'wailua homesteads', 'greymouth', "
#  "'saint-denis', 'saint-pierre', 'awjilah', 'rawson', 'malvan', 'hadibu', "
#  "'tamanrasset', 'saipan', 'nuuk', 'saint-joseph', 'talnakh', 'apodi', "
#  "'gillette', 'oranjemund', 'naze', 'ulladulla', 'newman', 'callao', 'natal', "
#  "'qamdo', 'leer', 'blackmans bay', 'alice springs', 'chonchi', "
#  '\'christchurch\', \'bilibino\', \'lazaro cardenas\', "hayma\'", '
#  "'vorgashor', 'puerto natales', 'papatowai', 'bereket', 'labytnangi', "
#  "'jamestown', 'haiku-pauwela', 'yigo village', 'yuzhno-kurilsk', 'adamstown', "
#  "'dinguiraye', 'al jawf', 'keningau', 'portland', 'port alfred', 'ilulissat', "
#  "'hamilton', 'tarauaca', 'port lincoln', 'tazovsky', 'shyroke', 'aykhal', "
#  "'selfoss', 'qaqortoq', 'nizhneudinsk', 'ust-nera', 'lensk', 'kenora', "
#  "'rosarito', 'kavieng', 'rio casca', 'wenchang', 'minas de marcona', "
#  "'ushuaia', 'fortuna', 'abadeh', 'brookings', 'takamaka', 'arraial do cabo', "
#  "'remire-montjoly', 'kingston', 'vangaindrano', 'dudinka', 'choibalsan', "
#  '\'utrik\', \'karakoyunlu\', \'iwanai\', "mil\'kovo", \'lihue\', \'weno\', '
#  "'coquimbo', 'sofifi', 'olonkinbyen', 'yamada', 'catriel', 'polyarnyye zori', "
#  "'aasiaat', 'aleksandrovsk-sakhalinskiy', 'ambovombe', 'tranovaho', 'ulan "
#  "bator', 'antofagasta', 'tura', 'sandnessjoen', 'devinuwara', 'nishinoomote', "
#  "'linxia chengguanzhen', 'iqaluit', 'invercargill', 'manadhoo', 'kenai', "
#  '"bich\'vinta", \'mocimboa\', \'tual\', \'ribeira grande\', \'lycksele\', '
#  "'broken hill', 'juan de ayolas', 'necochea', 'haimen', 'vadso', 'seogwipo', "
#  "'lushun']")

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 589

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
   
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{query_url}{city}"
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
            # Parse the JSON and retrieve data
            city_data_response = requests.get(city_url)
            city_data_response.raise_for_status()
            city_data_json = city_data_response.json()
        
          # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
            city_lat = city_data_json['coord']['lat']
            city_lng = city_data_json['coord']['lon']
            city_max_temp = city_data_json['main']['temp_max']
            city_humidity = city_data_json['main']['humidity']
            city_clouds = city_data_json['clouds']['all']
            city_wind = city_data_json['wind']['speed']
            city_country = city_data_json['sys']['country']
            city_date = city_data_json['dt']
        
        # Append the City information into city_data list
            city_data.append({
                "City": city,
                "Lat": city_lat,
                "Lng": city_lng,
                "Max Temp": city_max_temp,
                "Humidity": city_humidity,
                "Cloudiness": city_clouds,
                "Wind Speed": city_wind,
                "Country": city_country,
                "Date": city_date
            })
            
    except requests.exceptions.HTTPError as err:
            print(f"HTTP error occurred for {city}:{err}")
        
            
            
    # If an error is experienced, skip the city
    except Exception as err:
            print(f"An error occured for {city}: {err}")
            print("City not found. Skipping...")
            

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nemuro
# Processing Record 2 of Set 1 | edinburgh of the seven seas
# Processing Record 3 of Set 1 | udachny
# Processing Record 4 of Set 1 | lebu
# Processing Record 5 of Set 1 | boende
# Processing Record 6 of Set 1 | blackmans bay
# Processing Record 7 of Set 1 | grytviken
# Processing Record 8 of Set 1 | bataipora
# Processing Record 9 of Set 1 | vorgashor
# Processing Record 10 of Set 1 | mvomero
# Processing Record 11 of Set 1 | korla
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | hawaiian paradise park
# Processing Record 14 of Set 1 | kolondieba
# Processing Record 15 of Set 1 | carnarvon
# Processing Record 16 of Set 1 | rongelap
# Processing Record 17 of Set 1 | yangor
# HTTP error occurred for yangor:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=yangor
# Processing Record 18 of Set 1 | alta
# Processing Record 19 of Set 1 | keren
# Processing Record 20 of Set 1 | port augusta
# Processing Record 21 of Set 1 | mount gambier
# Processing Record 22 of Set 1 | port-aux-francais
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | waitangi
# Processing Record 25 of Set 1 | margaret river
# Processing Record 26 of Set 1 | at taj
# Processing Record 27 of Set 1 | yeniseysk
# Processing Record 28 of Set 1 | 'ohonua
# HTTP error occurred for 'ohonua:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q='ohonua
# Processing Record 29 of Set 1 | iqaluit
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | bilibino
# Processing Record 33 of Set 1 | klyuchi
# Processing Record 34 of Set 1 | mana
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | st. john's
# Processing Record 38 of Set 1 | papatowai
# Processing Record 39 of Set 1 | namsos
# Processing Record 40 of Set 1 | polva
# Processing Record 41 of Set 1 | vila franca do campo
# Processing Record 42 of Set 1 | kingston
# Processing Record 43 of Set 1 | la paz
# Processing Record 44 of Set 1 | baihar
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | iskateley
# Processing Record 47 of Set 1 | puerto natales
# Processing Record 48 of Set 1 | obo
# Processing Record 49 of Set 1 | venice
# Processing Record 50 of Set 1 | noumea
# Processing Record 0 of Set 2 | kapuskasing
# Processing Record 1 of Set 2 | lazaro cardenas
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | saint-pierre
# Processing Record 4 of Set 2 | yermentau
# Processing Record 5 of Set 2 | ushuaia
# Processing Record 6 of Set 2 | adamstown
# Processing Record 7 of Set 2 | anadyr
# Processing Record 8 of Set 2 | san salvo
# Processing Record 9 of Set 2 | manokwari
# Processing Record 10 of Set 2 | vila velha
# Processing Record 11 of Set 2 | colonia
# Processing Record 12 of Set 2 | manga
# Processing Record 13 of Set 2 | nar'yan-mar
# Processing Record 14 of Set 2 | polyarnyy
# Processing Record 15 of Set 2 | hamilton
# Processing Record 16 of Set 2 | taiohae
# HTTP error occurred for taiohae:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=taiohae
# Processing Record 17 of Set 2 | choma
# Processing Record 18 of Set 2 | maloye ganyushkino
# Processing Record 19 of Set 2 | nayudupet
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | college
# Processing Record 22 of Set 2 | qaqortoq
# Processing Record 23 of Set 2 | whitehorse
# Processing Record 24 of Set 2 | egilsstadir
# Processing Record 25 of Set 2 | talcahuano
# Processing Record 26 of Set 2 | ola
# Processing Record 27 of Set 2 | cargados carajos
# HTTP error occurred for cargados carajos:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=cargados%20carajos
# Processing Record 28 of Set 2 | sitka
# Processing Record 29 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 30 of Set 2 | chonchi
# Processing Record 31 of Set 2 | keflavik
# Processing Record 32 of Set 2 | tralee
# Processing Record 33 of Set 2 | tasbuget
# HTTP error occurred for tasbuget:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=tasbuget
# Processing Record 34 of Set 2 | saipan
# Processing Record 35 of Set 2 | ilulissat
# Processing Record 36 of Set 2 | wailua homesteads
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | olonkinbyen
# Processing Record 39 of Set 2 | benito garcia (el zorrillo)
# HTTP error occurred for benito garcia (el zorrillo):404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=benito%20garcia%20(el%20zorrillo)
# Processing Record 40 of Set 2 | utrik
# Processing Record 41 of Set 2 | franceville
# Processing Record 42 of Set 2 | muisne
# Processing Record 43 of Set 2 | lobamba
# Processing Record 44 of Set 2 | porto novo
# Processing Record 45 of Set 2 | pingdingshan
# Processing Record 46 of Set 2 | taltal
# Processing Record 47 of Set 2 | irymple
# Processing Record 48 of Set 2 | port elizabeth
# Processing Record 49 of Set 2 | mejit
# Processing Record 0 of Set 3 | longyearbyen
# Processing Record 1 of Set 3 | talnakh
# Processing Record 2 of Set 3 | kailua-kona
# Processing Record 3 of Set 3 | nabire
# Processing Record 4 of Set 3 | afaahiti
# Processing Record 5 of Set 3 | dryden
# Processing Record 6 of Set 3 | nadi
# Processing Record 7 of Set 3 | flin flon
# Processing Record 8 of Set 3 | aykhal
# Processing Record 9 of Set 3 | vadso
# Processing Record 10 of Set 3 | yellowknife
# Processing Record 11 of Set 3 | inarajan village
# Processing Record 12 of Set 3 | ar ruways
# Processing Record 13 of Set 3 | kibondo
# Processing Record 14 of Set 3 | minas de marcona
# Processing Record 15 of Set 3 | xiva
# Processing Record 16 of Set 3 | yuzhno-kurilsk
# Processing Record 17 of Set 3 | vilyuchinsk
# Processing Record 18 of Set 3 | ati
# Processing Record 19 of Set 3 | matoury
# Processing Record 20 of Set 3 | zheleznodorozhnyy
# Processing Record 21 of Set 3 | wotho
# Processing Record 22 of Set 3 | celestun
# Processing Record 23 of Set 3 | aasiaat
# Processing Record 24 of Set 3 | kapa'a
# Processing Record 25 of Set 3 | pathein
# Processing Record 26 of Set 3 | antalaha
# Processing Record 27 of Set 3 | meridian
# Processing Record 28 of Set 3 | kikwit
# Processing Record 29 of Set 3 | haiku-pauwela
# Processing Record 30 of Set 3 | mao
# Processing Record 31 of Set 3 | puerto cabezas
# Processing Record 32 of Set 3 | kununurra
# Processing Record 33 of Set 3 | port lincoln
# Processing Record 34 of Set 3 | akureyri
# Processing Record 35 of Set 3 | booneville
# Processing Record 36 of Set 3 | darwin
# Processing Record 37 of Set 3 | remire-montjoly
# Processing Record 38 of Set 3 | isafjordur
# Processing Record 39 of Set 3 | sandnessjoen
# Processing Record 40 of Set 3 | la'ie
# Processing Record 41 of Set 3 | newman
# Processing Record 42 of Set 3 | bay roberts
# Processing Record 43 of Set 3 | amurzet
# Processing Record 44 of Set 3 | kilinochchi
# Processing Record 45 of Set 3 | galesong
# Processing Record 46 of Set 3 | west island
# Processing Record 47 of Set 3 | lerwick
# Processing Record 48 of Set 3 | lihue
# Processing Record 49 of Set 3 | port hedland
# Processing Record 0 of Set 4 | ilheus
# Processing Record 1 of Set 4 | lorengau
# Processing Record 2 of Set 4 | santa ana
# Processing Record 3 of Set 4 | eldama ravine
# Processing Record 4 of Set 4 | tolanaro
# Processing Record 5 of Set 4 | ahau
# HTTP error occurred for ahau:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=ahau
# Processing Record 6 of Set 4 | kangding
# Processing Record 7 of Set 4 | grand rapids
# Processing Record 8 of Set 4 | belmonte
# Processing Record 9 of Set 4 | east london
# Processing Record 10 of Set 4 | pico truncado
# Processing Record 11 of Set 4 | dudinka
# Processing Record 12 of Set 4 | thompson
# Processing Record 13 of Set 4 | constantia
# Processing Record 14 of Set 4 | rawson
# Processing Record 15 of Set 4 | vernon
# Processing Record 16 of Set 4 | zahir pir
# Processing Record 17 of Set 4 | jinjiang
# Processing Record 18 of Set 4 | broken hill
# Processing Record 19 of Set 4 | harlingen
# Processing Record 20 of Set 4 | port mathurin
# Processing Record 21 of Set 4 | nikolayevka
# Processing Record 22 of Set 4 | cable beach
# HTTP error occurred for cable beach:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=cable%20beach
# Processing Record 23 of Set 4 | alzamay
# Processing Record 24 of Set 4 | nizhniy odes
# Processing Record 25 of Set 4 | tranovaho
# HTTP error occurred for tranovaho:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=tranovaho
# Processing Record 26 of Set 4 | klaksvik
# Processing Record 27 of Set 4 | ust'-barguzin
# Processing Record 28 of Set 4 | mar del plata
# Processing Record 29 of Set 4 | pisco
# Processing Record 30 of Set 4 | kolonia town
# Processing Record 31 of Set 4 | alupka
# Processing Record 32 of Set 4 | kulattur
# Processing Record 33 of Set 4 | presidente medici
# Processing Record 34 of Set 4 | la passe
# Processing Record 35 of Set 4 | mount isa
# Processing Record 36 of Set 4 | puerto san carlos
# HTTP error occurred for puerto san carlos:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=puerto%20san%20carlos
# Processing Record 37 of Set 4 | yashkul'
# Processing Record 38 of Set 4 | kone
# Processing Record 39 of Set 4 | soto la marina
# Processing Record 40 of Set 4 | touros
# Processing Record 41 of Set 4 | codrington
# Processing Record 42 of Set 4 | olyokminsk
# Processing Record 43 of Set 4 | buta
# Processing Record 44 of Set 4 | tommot
# Processing Record 45 of Set 4 | taro
# Processing Record 46 of Set 4 | ta`u
# Processing Record 47 of Set 4 | pasni
# Processing Record 48 of Set 4 | hilo
# Processing Record 49 of Set 4 | mahina
# Processing Record 0 of Set 5 | pierre
# Processing Record 1 of Set 5 | paragominas
# Processing Record 2 of Set 5 | uturoa
# Processing Record 3 of Set 5 | loukhi
# Processing Record 4 of Set 5 | machico
# Processing Record 5 of Set 5 | cabedelo
# Processing Record 6 of Set 5 | greymouth
# Processing Record 7 of Set 5 | nizhnesortymskiy
# Processing Record 8 of Set 5 | lethem
# Processing Record 9 of Set 5 | okha
# Processing Record 10 of Set 5 | chibougamau
# Processing Record 11 of Set 5 | governor's harbour
# HTTP error occurred for governor's harbour:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=governor's%20harbour
# Processing Record 12 of Set 5 | georgetown
# Processing Record 13 of Set 5 | bozdar wada
# Processing Record 14 of Set 5 | tanjung pandan
# Processing Record 15 of Set 5 | fomento
# Processing Record 16 of Set 5 | nova sintra
# Processing Record 17 of Set 5 | brisas de zicatela
# Processing Record 18 of Set 5 | slave lake
# Processing Record 19 of Set 5 | broome
# Processing Record 20 of Set 5 | namasuba
# Processing Record 21 of Set 5 | goya
# Processing Record 22 of Set 5 | am djarass
# HTTP error occurred for am djarass:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=am%20djarass
# Processing Record 23 of Set 5 | thetford-mines
# Processing Record 24 of Set 5 | utmanzai
# Processing Record 25 of Set 5 | san antonio de pale
# Processing Record 26 of Set 5 | taloqan
# Processing Record 27 of Set 5 | kodiak
# Processing Record 28 of Set 5 | godhra
# Processing Record 29 of Set 5 | ladario
# Processing Record 30 of Set 5 | alofi
# Processing Record 31 of Set 5 | puerto aysen
# Processing Record 32 of Set 5 | igrim
# Processing Record 33 of Set 5 | crane
# Processing Record 34 of Set 5 | malango
# Processing Record 35 of Set 5 | ytyk-kyuyel'
# HTTP error occurred for ytyk-kyuyel':404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=ytyk-kyuyel'
# Processing Record 36 of Set 5 | callao
# Processing Record 37 of Set 5 | rantauprapat
# Processing Record 38 of Set 5 | mount horeb
# Processing Record 39 of Set 5 | soe
# Processing Record 40 of Set 5 | punta arenas
# Processing Record 41 of Set 5 | zlocieniec
# Processing Record 42 of Set 5 | waingapu
# Processing Record 43 of Set 5 | wiwili
# Processing Record 44 of Set 5 | yagry
# HTTP error occurred for yagry:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=yagry
# Processing Record 45 of Set 5 | prince rupert
# Processing Record 46 of Set 5 | alice springs
# Processing Record 47 of Set 5 | xilin hot
# Processing Record 48 of Set 5 | praia da vitoria
# Processing Record 49 of Set 5 | inhambane
# Processing Record 0 of Set 6 | fort st. john
# Processing Record 1 of Set 6 | amga
# Processing Record 2 of Set 6 | kodinar
# Processing Record 3 of Set 6 | pyin oo lwin
# Processing Record 4 of Set 6 | labrador city
# Processing Record 5 of Set 6 | sinabang
# Processing Record 6 of Set 6 | pontianak
# Processing Record 7 of Set 6 | wingham
# Processing Record 8 of Set 6 | stanley
# Processing Record 9 of Set 6 | turkmenbasy
# Processing Record 10 of Set 6 | suva
# Processing Record 11 of Set 6 | cabo san lucas
# Processing Record 12 of Set 6 | zangguy
# HTTP error occurred for zangguy:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=zangguy
# Processing Record 13 of Set 6 | new norfolk
# Processing Record 14 of Set 6 | fortuna
# Processing Record 15 of Set 6 | bereznik
# Processing Record 16 of Set 6 | gislaved
# Processing Record 17 of Set 6 | saint croix
# Processing Record 18 of Set 6 | sirte
# Processing Record 19 of Set 6 | teguise
# Processing Record 20 of Set 6 | we
# HTTP error occurred for we:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=we
# Processing Record 21 of Set 6 | badger
# Processing Record 22 of Set 6 | tangalle
# Processing Record 23 of Set 6 | otjimbingwe
# Processing Record 24 of Set 6 | hultsfred
# Processing Record 25 of Set 6 | claremore
# Processing Record 26 of Set 6 | onega
# Processing Record 27 of Set 6 | atafu village
# Processing Record 28 of Set 6 | lebanon
# Processing Record 29 of Set 6 | ancud
# Processing Record 30 of Set 6 | hotan
# Processing Record 31 of Set 6 | dauphin
# Processing Record 32 of Set 6 | cockburn town
# Processing Record 33 of Set 6 | nagqu
# Processing Record 34 of Set 6 | chaoyang
# Processing Record 35 of Set 6 | hopelchen
# Processing Record 36 of Set 6 | bocas del toro
# Processing Record 37 of Set 6 | nealtican
# Processing Record 38 of Set 6 | dazuocun
# Processing Record 39 of Set 6 | ayacucho
# Processing Record 40 of Set 6 | carutapera
# Processing Record 41 of Set 6 | mandalgovi
# Processing Record 42 of Set 6 | turpan
# Processing Record 43 of Set 6 | cadale
# Processing Record 44 of Set 6 | port macquarie
# Processing Record 45 of Set 6 | sonsorol village
# HTTP error occurred for sonsorol village:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=sonsorol%20village
# Processing Record 46 of Set 6 | margate
# Processing Record 47 of Set 6 | solnechnyy
# Processing Record 48 of Set 6 | nishinoomote
# Processing Record 49 of Set 6 | guerrero negro
# Processing Record 0 of Set 7 | rehoboth
# Processing Record 1 of Set 7 | abu jibeha
# Processing Record 2 of Set 7 | kerikeri
# Processing Record 3 of Set 7 | invercargill
# Processing Record 4 of Set 7 | sydney
# Processing Record 5 of Set 7 | assai
# Processing Record 6 of Set 7 | pangkalanbuun
# Processing Record 7 of Set 7 | aldinga beach
# Processing Record 8 of Set 7 | anna regina
# Processing Record 9 of Set 7 | bom jesus
# Processing Record 10 of Set 7 | qinzhou
# Processing Record 11 of Set 7 | salinopolis
# Processing Record 12 of Set 7 | gunjur
# Processing Record 13 of Set 7 | torrevieja
# Processing Record 14 of Set 7 | howrah
# Processing Record 15 of Set 7 | tucuma
# Processing Record 16 of Set 7 | tadine
# Processing Record 17 of Set 7 | exu
# Processing Record 18 of Set 7 | ust-nera
# Processing Record 19 of Set 7 | rabigh
# Processing Record 20 of Set 7 | happy valley-goose bay
# Processing Record 21 of Set 7 | itoman
# Processing Record 22 of Set 7 | douz
# Processing Record 23 of Set 7 | honiton
# Processing Record 24 of Set 7 | bikin
# Processing Record 25 of Set 7 | karasburg
# Processing Record 26 of Set 7 | farshut
# Processing Record 27 of Set 7 | toga village
# HTTP error occurred for toga village:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=toga%20village
# Processing Record 28 of Set 7 | fale old settlement
# Processing Record 29 of Set 7 | tual
# Processing Record 30 of Set 7 | kimovsk
# Processing Record 31 of Set 7 | pandan
# Processing Record 32 of Set 7 | kourou
# Processing Record 33 of Set 7 | media luna
# Processing Record 34 of Set 7 | box elder
# Processing Record 35 of Set 7 | sokoni
# Processing Record 36 of Set 7 | mayen abun
# HTTP error occurred for mayen abun:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=mayen%20abun
# Processing Record 37 of Set 7 | tema
# Processing Record 38 of Set 7 | antonio enes
# Processing Record 39 of Set 7 | muli
# Processing Record 40 of Set 7 | ak-dovurak
# Processing Record 41 of Set 7 | xining
# Processing Record 42 of Set 7 | kearney
# Processing Record 43 of Set 7 | port isabel
# Processing Record 44 of Set 7 | lure
# Processing Record 45 of Set 7 | laojunmiao
# Processing Record 46 of Set 7 | ingeniero jacobacci
# Processing Record 47 of Set 7 | kavaratti
# Processing Record 48 of Set 7 | bargara
# HTTP error occurred for bargara:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=bargara
# Processing Record 49 of Set 7 | tura
# Processing Record 0 of Set 8 | smithers
# Processing Record 1 of Set 8 | taoudenni
# Processing Record 2 of Set 8 | nizhneudinsk
# Processing Record 3 of Set 8 | betio village
# Processing Record 4 of Set 8 | palmwoods
# Processing Record 5 of Set 8 | yarmouth
# Processing Record 6 of Set 8 | kutum
# Processing Record 7 of Set 8 | kuusamo
# Processing Record 8 of Set 8 | crescent city
# Processing Record 9 of Set 8 | ceeldheer
# Processing Record 10 of Set 8 | pacific grove
# Processing Record 11 of Set 8 | kingsford
# Processing Record 12 of Set 8 | dalnegorsk
# Processing Record 13 of Set 8 | larne
# Processing Record 14 of Set 8 | krychaw
# Processing Record 15 of Set 8 | san patricio
# Processing Record 16 of Set 8 | kargasok
# Processing Record 17 of Set 8 | guilin
# Processing Record 18 of Set 8 | washington
# Processing Record 19 of Set 8 | luis correia
# Processing Record 20 of Set 8 | susuman
# Processing Record 21 of Set 8 | noyemberyan
# Processing Record 22 of Set 8 | puerto deseado
# Processing Record 23 of Set 8 | westport
# Processing Record 24 of Set 8 | pariaman
# Processing Record 25 of Set 8 | qamdo
# Processing Record 26 of Set 8 | itamaraju
# Processing Record 27 of Set 8 | palikir - national government center
# Processing Record 28 of Set 8 | pujehun
# Processing Record 29 of Set 8 | kurchatov
# Processing Record 30 of Set 8 | sorsk
# Processing Record 31 of Set 8 | tulun
# Processing Record 32 of Set 8 | auki
# Processing Record 33 of Set 8 | angicos
# Processing Record 34 of Set 8 | lae
# Processing Record 35 of Set 8 | zabaykal'sk
# Processing Record 36 of Set 8 | mawu
# Processing Record 37 of Set 8 | yekaterinoslavka
# Processing Record 38 of Set 8 | okhotsk
# Processing Record 39 of Set 8 | sarankhola
# Processing Record 40 of Set 8 | ain kercha
# Processing Record 41 of Set 8 | trancoso
# Processing Record 42 of Set 8 | aoulef
# Processing Record 43 of Set 8 | yunguyo
# Processing Record 44 of Set 8 | namibe
# Processing Record 45 of Set 8 | faya-largeau
# Processing Record 46 of Set 8 | rabo de peixe
# Processing Record 47 of Set 8 | sur
# Processing Record 48 of Set 8 | miagao
# Processing Record 49 of Set 8 | weno
# Processing Record 0 of Set 9 | canchungo
# Processing Record 1 of Set 9 | labytnangi
# Processing Record 2 of Set 9 | sayat
# Processing Record 3 of Set 9 | trairi
# Processing Record 4 of Set 9 | marinette
# Processing Record 5 of Set 9 | rikaze
# Processing Record 6 of Set 9 | richards bay
# Processing Record 7 of Set 9 | fort mcmurray
# Processing Record 8 of Set 9 | guachochi
# HTTP error occurred for guachochi:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=guachochi
# Processing Record 9 of Set 9 | avarua
# Processing Record 10 of Set 9 | kayenta
# Processing Record 11 of Set 9 | cao bang
# Processing Record 12 of Set 9 | manicore
# Processing Record 13 of Set 9 | gobo
# Processing Record 14 of Set 9 | chake chake
# Processing Record 15 of Set 9 | albuquerque
# Processing Record 16 of Set 9 | urangan
# Processing Record 17 of Set 9 | belyy yar
# Processing Record 18 of Set 9 | el calafate
# Processing Record 19 of Set 9 | maxixe
# Processing Record 20 of Set 9 | igarka
# Processing Record 21 of Set 9 | khash
# Processing Record 22 of Set 9 | rakops
# Processing Record 23 of Set 9 | ugbokpo
# Processing Record 24 of Set 9 | geraldton
# Processing Record 25 of Set 9 | nouadhibou
# Processing Record 26 of Set 9 | khadan khak
# Processing Record 27 of Set 9 | sanchor
# Processing Record 28 of Set 9 | springbok
# Processing Record 29 of Set 9 | lobujya
# Processing Record 30 of Set 9 | fendou
# Processing Record 31 of Set 9 | merowe
# Processing Record 32 of Set 9 | zaragoza
# Processing Record 33 of Set 9 | puerto armuelles
# Processing Record 34 of Set 9 | revda
# Processing Record 35 of Set 9 | port glaud
# HTTP error occurred for port glaud:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=port%20glaud
# Processing Record 36 of Set 9 | flying fish cove
# Processing Record 37 of Set 9 | madukkur
# Processing Record 38 of Set 9 | nuevitas
# Processing Record 39 of Set 9 | mariental
# Processing Record 40 of Set 9 | tazovsky
# Processing Record 41 of Set 9 | ban phe
# HTTP error occurred for ban phe:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=ban%20phe
# Processing Record 42 of Set 9 | at taraf
# Processing Record 43 of Set 9 | alaghsas
# Processing Record 44 of Set 9 | lepsy
# Processing Record 45 of Set 9 | eyl
# Processing Record 46 of Set 9 | sierpc
# Processing Record 47 of Set 9 | molde
# Processing Record 48 of Set 9 | marsa alam
# Processing Record 49 of Set 9 | nalerigu
# HTTP error occurred for nalerigu:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=nalerigu
# Processing Record 0 of Set 10 | wynyard
# Processing Record 1 of Set 10 | pemangkat
# Processing Record 2 of Set 10 | verkhnevilyuysk
# Processing Record 3 of Set 10 | tarawa
# Processing Record 4 of Set 10 | mega
# Processing Record 5 of Set 10 | hadibu
# Processing Record 6 of Set 10 | arrifes
# Processing Record 7 of Set 10 | karratha
# Processing Record 8 of Set 10 | pechora
# Processing Record 9 of Set 10 | medina
# Processing Record 10 of Set 10 | kulhudhuffushi
# Processing Record 11 of Set 10 | alo
# Processing Record 12 of Set 10 | howard springs
# Processing Record 13 of Set 10 | al bardiyah
# Processing Record 14 of Set 10 | ishikawa
# Processing Record 15 of Set 10 | antsiranana
# Processing Record 16 of Set 10 | narvik
# Processing Record 17 of Set 10 | hakui
# Processing Record 18 of Set 10 | sabancuy
# Processing Record 19 of Set 10 | mineros
# Processing Record 20 of Set 10 | vorkuta
# Processing Record 21 of Set 10 | cabinda
# Processing Record 22 of Set 10 | bengkulu
# Processing Record 23 of Set 10 | genhe
# Processing Record 24 of Set 10 | ciudad acuna
# Processing Record 25 of Set 10 | kerman
# Processing Record 26 of Set 10 | santana
# Processing Record 27 of Set 10 | yatou
# Processing Record 28 of Set 10 | ribeira brava
# Processing Record 29 of Set 10 | puerto baquerizo moreno
# Processing Record 30 of Set 10 | ba
# HTTP error occurred for ba:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=ba
# Processing Record 31 of Set 10 | rotterdam
# Processing Record 32 of Set 10 | viveiro
# Processing Record 33 of Set 10 | kathmandu
# Processing Record 34 of Set 10 | kultali
# HTTP error occurred for kultali:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=kultali
# Processing Record 35 of Set 10 | inyonga
# Processing Record 36 of Set 10 | port alfred
# Processing Record 37 of Set 10 | gillette
# Processing Record 38 of Set 10 | boguchany
# Processing Record 39 of Set 10 | hayma'
# HTTP error occurred for hayma':404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=hayma'
# Processing Record 40 of Set 10 | beau vallon
# Processing Record 41 of Set 10 | saint-francois
# Processing Record 42 of Set 10 | kashin
# Processing Record 43 of Set 10 | sorong
# Processing Record 44 of Set 10 | carmen
# Processing Record 45 of Set 10 | nova xavantina
# Processing Record 46 of Set 10 | emerald
# Processing Record 47 of Set 10 | beboto
# Processing Record 48 of Set 10 | capao da canoa
# Processing Record 49 of Set 10 | havre
# Processing Record 0 of Set 11 | bridlington
# Processing Record 1 of Set 11 | eaglehawk
# Processing Record 2 of Set 11 | wuwei
# Processing Record 3 of Set 11 | al kharj
# Processing Record 4 of Set 11 | bubaque
# Processing Record 5 of Set 11 | beruniy
# Processing Record 6 of Set 11 | driefontein
# Processing Record 7 of Set 11 | saint-philippe
# Processing Record 8 of Set 11 | severo-yeniseyskiy
# Processing Record 9 of Set 11 | antofagasta
# Processing Record 10 of Set 11 | quellon
# Processing Record 11 of Set 11 | jeddah
# Processing Record 12 of Set 11 | nisa
# Processing Record 13 of Set 11 | jumla
# Processing Record 14 of Set 11 | dharampuri
# Processing Record 15 of Set 11 | ust'-ilimsk
# Processing Record 16 of Set 11 | huarmey
# Processing Record 17 of Set 11 | cheria
# Processing Record 18 of Set 11 | urengoy
# Processing Record 19 of Set 11 | grand falls-windsor
# Processing Record 20 of Set 11 | acarau
# Processing Record 21 of Set 11 | noshiro
# Processing Record 22 of Set 11 | shurugwi
# Processing Record 23 of Set 11 | kattivakkam
# Processing Record 24 of Set 11 | chippewa falls
# Processing Record 25 of Set 11 | conception bay south
# Processing Record 26 of Set 11 | al quwayrah
# Processing Record 27 of Set 11 | ponta delgada
# Processing Record 28 of Set 11 | sarkand
# Processing Record 29 of Set 11 | bagayevskaya
# Processing Record 30 of Set 11 | tubarjal
# Processing Record 31 of Set 11 | freetown
# Processing Record 32 of Set 11 | landau in der pfalz
# Processing Record 33 of Set 11 | bang phae
# Processing Record 34 of Set 11 | dunedin
# Processing Record 35 of Set 11 | kirakira
# Processing Record 36 of Set 11 | robertsport
# Processing Record 37 of Set 11 | katabu
# Processing Record 38 of Set 11 | kwang binh
# Processing Record 39 of Set 11 | tomatlan
# Processing Record 40 of Set 11 | jatiroto
# Processing Record 41 of Set 11 | nikopol
# Processing Record 42 of Set 11 | kulia village
# HTTP error occurred for kulia village:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=kulia%20village
# Processing Record 43 of Set 11 | tsumeb
# Processing Record 44 of Set 11 | belokurikha
# Processing Record 45 of Set 11 | aweil
# Processing Record 46 of Set 11 | krasnovishersk
# Processing Record 47 of Set 11 | salekhard
# Processing Record 48 of Set 11 | zaraza
# Processing Record 49 of Set 11 | marsaskala
# HTTP error occurred for marsaskala:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=marsaskala
# Processing Record 0 of Set 12 | vingt cinq
# HTTP error occurred for vingt cinq:404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=ac68eb747d7d71f54c8c302a89439a32&units=metric&q=vingt%20cinq
# Processing Record 1 of Set 12 | port-vila
# Processing Record 2 of Set 12 | mpulungu
# Processing Record 3 of Set 12 | phek
# Processing Record 4 of Set 12 | belen
# Processing Record 5 of Set 12 | utiel
# Processing Record 6 of Set 12 | takoradi
# Processing Record 7 of Set 12 | fada
# Processing Record 8 of Set 12 | hobyo
# Processing Record 9 of Set 12 | mangrol
# Processing Record 10 of Set 12 | sedalia
# Processing Record 11 of Set 12 | northfield
# Processing Record 12 of Set 12 | rio grande
# Processing Record 13 of Set 12 | kem'
# Processing Record 14 of Set 12 | kaplice
# Processing Record 15 of Set 12 | zhongxing
# Processing Record 16 of Set 12 | san jose de feliciano
# Processing Record 17 of Set 12 | angra do heroismo
# Processing Record 18 of Set 12 | smara
# Processing Record 19 of Set 12 | hojo
# Processing Record 20 of Set 12 | shingu
# Processing Record 21 of Set 12 | natal
# Processing Record 22 of Set 12 | siirt
# Processing Record 23 of Set 12 | lagos
# Processing Record 24 of Set 12 | nyurba
# Processing Record 25 of Set 12 | springfield
# Processing Record 26 of Set 12 | kilindoni
# Processing Record 27 of Set 12 | crookston
# Processing Record 28 of Set 12 | khark
# Processing Record 29 of Set 12 | jamiltepec
# Processing Record 30 of Set 12 | tuni
# Processing Record 31 of Set 12 | zhezkent
# Processing Record 32 of Set 12 | mamedkala
# Processing Record 33 of Set 12 | juan griego
# Processing Record 34 of Set 12 | akrehamn
# Processing Record 35 of Set 12 | bamboo flat
# Processing Record 36 of Set 12 | ampanihy
# Processing Record 37 of Set 12 | malakal
# Processing Record 38 of Set 12 | sault ste. marie
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          559
# Lat           559
# Lng           559
# Max Temp      559
# Humidity      559
# Cloudiness    559
# Wind Speed    559
# Country       559
# Date          559
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                       nemuro  43.3236  145.5750     20.32        67
# 1  edinburgh of the seven seas -37.0676  -12.3116     10.71        75
# 2                      udachny  66.4167  112.4000      0.14        66
# 3                         lebu -37.6167  -73.6500      7.98        88
# 4                       boende  -0.2167   20.8667     22.06        91
#
#    Cloudiness  Wind Speed Country        Date
# 0           0        2.60      JP  1726629757
# 1         100        7.20      SH  1726629759
# 2          99        8.01      RU  1726629761
# 3         100        1.62      CL  1726629762
# 4          53        1.13      CD  1726629763

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                             nemuro  43.3236  145.5750     20.32        67
# 1        edinburgh of the seven seas -37.0676  -12.3116     10.71        75
# 2                            udachny  66.4167  112.4000      0.14        66
# 3                               lebu -37.6167  -73.6500      7.98        88
# 4                             boende  -0.2167   20.8667     22.06        91
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 0        2.60      JP  1726629757
# 1               100        7.20      SH  1726629759
# 2                99        8.01      RU  1726629761
# 3               100        1.62      CL  1726629762
# 4                53        1.13      CD  1726629763

# %%
# Build scatter plot for latitude vs. temperature
city_max = city_data_df
plt.scatter(city_max['Lat'], city_max['Max Temp'], edgecolor='black', linewidth=2)

# Incorporate the other graph properties
plt.title('City Max Latitude vs. Temperature (9-17-2024)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_max['Lat'], city_max['Humidity'], edgecolor='black', linewidth=2)

# Incorporate the other graph properties
plt.title('City Latitude vs. Temperature (9-17-2024)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_max['Lat'], city_max['Cloudiness'], edgecolor='black', linewidth=2)

# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudiness (09-17-2024)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_max['Lat'], city_max['Wind Speed'], edgecolor='black', linewidth=2)

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed (09-17-2024)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def renderChart(x,y,title):
    slope,intercept,rvalue = linregress(x,y)[:3]
    print(f'The r^2-value is: {rvalue}')
    plt.plot(x, x * slope + intercept, 'r' )
    plt.scatter(x,y, edgecolor='black', linewidth=2)
    plt.xlabel('Latitude')
    plt.ylabel(title)
    plt.grid()
    plt.annotate(f'y = X{slope:.2f} + {intercept:.2f}', [x.min(),y.min()], color='r', fontsize=14)
    plt.title(f'Latitude vs {title} (09/16/24)')
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_max[city_max.Lat>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           nemuro  43.3236  145.5750     20.32        67           0
# 2          udachny  66.4167  112.4000      0.14        66          99
# 8        vorgashor  67.5833   63.9500      8.40        89          86
# 10           korla  41.7597   86.1469     25.99        26          96
# 11          bethel  41.3712  -73.4140     17.17        92           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      JP  1726629757
# 2              8.01      RU  1726629761
# 8              5.01      RU  1726629768
# 10             2.53      CN  1726629770
# 11             1.54      US  1726629544

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_max[city_max.Lat < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1        edinburgh of the seven seas -37.0676  -12.3116     10.71        75
# 3                               lebu -37.6167  -73.6500      7.98        88
# 4                             boende  -0.2167   20.8667     22.06        91
# 5                      blackmans bay -43.0167  147.3167      8.74        88
# 6                          grytviken -54.2811  -36.5092      2.06        90
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1               100        7.20      SH  1726629759
# 3               100        1.62      CL  1726629762
# 4                53        1.13      CD  1726629763
# 5                99        0.45      AU  1726629764
# 6                98        9.50      GS  1726629765

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x = northern_hemi_df.Lat
y = northern_hemi_df["Max Temp"]

renderChart(x,y, "Max Temp")
# Out:
# The r^2-value is: -0.8033293900502885

# %%
# Linear regression on Southern Hemisphere
x = southern_hemi_df.Lat
y = southern_hemi_df["Max Temp"]

renderChart(x,y, "Max Temp")
# Out:
# The r^2-value is: 0.7673381926682172

# %% [markdown]
# **Discussion about the linear relationship:** Per review temperature increases closer to the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df.Lat
y = northern_hemi_df["Humidity"]

renderChart(x,y, "Humidity")
# Out:
# The r^2-value is: -0.00027958083277774756

# %%
# Southern Hemisphere
x = southern_hemi_df.Lat
y = southern_hemi_df["Humidity"]

renderChart(x,y, "Humidity")
# Out:
# The r^2-value is: -0.02138696682357281

# %% [markdown]
# **Discussion about the linear relationship:** Per review humidity appears to increase closer to the equator.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df.Lat
y = northern_hemi_df["Cloudiness"]

renderChart(x,y, "Cloudiness")
# Out:
# The r^2-value is: 0.1363538243705599

# %%
# Southern Hemisphere
x = southern_hemi_df.Lat
y = southern_hemi_df["Cloudiness"]

renderChart(x,y, "Cloudiness")
# Out:
# The r^2-value is: 0.04221075571869753

# %% [markdown]
# **Discussion about the linear relationship:** Per review nothern hemisphere does not have any variance, as to southern cloudiness increases near equator.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df.Lat
y = northern_hemi_df["Wind Speed"]

renderChart(x,y, "Wind Speed")
# Out:
# The r^2-value is: 0.01794406523828552

# %%
# Southern Hemisphere
x = southern_hemi_df.Lat
y = southern_hemi_df["Wind Speed"]

renderChart(x,y, "Wind Speed")
# Out:
# The r^2-value is: -0.09544055463978617

# %% [markdown]
# **Discussion about the linear relationship:** Per review northern hemisphere wind speeds appear consistent as opposed to the southern hemisphere which shows less density.
